# %% [markdown]
# <a href="https://colab.research.google.com/github/ag-ss-78/python_code/blob/main/data_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
position = 0
walk = [position]
for i in range(100):
    step = random.choice([1,-1])
    position += step
    walk.append(position)
print(walk)
plt.plot(walk)
plt.show()
# Out:
# [0, 1, 0, -1, -2, -3, -4, -5, -6, -7, -6, -5, -6, -7, -8, -7, -6, -5, -6, -7, -6, -7, -8, -9, -8, -7, -8, -7, -6, -7, -8, -7, -6, -5, -6, -7, -6, -5, -4, -3, -2, -3, -4, -3, -2, -1, 0, -1, -2, -3, -2, -3, -4, -3, -4, -3, -2, -3, -2, -3, -4, -5, -4, -3, -2, -1, -2, -1, -2, -1, -2, -1, -2, -1, 0, -1, -2, -3, -4, -3, -2, -1, 0, 1, 0, 1, 2, 3, 2, 1, 0, 1, 2, 1, 2, 1, 2, 1, 2, 1, 0]
